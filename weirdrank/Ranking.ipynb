# %%
import json
from collections import defaultdict

# %%
rank=[]

# %%
def rank_n(t_list,n):
    for t in t_list:
        print(t)
    return 1

def write_json(data_list):
    outfile = open('Rupali.json', 'a+')
    for data in data_list:
        json.dump(data, outfile)
        outfile.write('\n')
    outfile.close()

# %%
f1=open("./dataset/top500.json","r")
lines=[line for line in f1] 
titles,urls=[json.loads(line)['title'] for line in lines], [json.loads(line)['url'] for line in lines]


# data['title']=titles[0]
# data['url']=urls[0]
# data['rank']=1

cnt=0
data_list=[]
while cnt !=500:
    for i in range(10):
        data={}
        rank=input(titles[cnt])
        data['url']=urls[cnt]
        data['title']=titles[cnt]
        data['rank']=rank
        data_list.append(data)
        cnt+=1
    write_json(data_list)
    print (cnt, " docs done..")
        
        
# write_json(data)
# Out:
# French 'Spiderman' climbs Barcelona skyscraper harness-free3
# Flying drone smuggles cell-phone, saw blade into Danish prison0
# 'No can do', Heinz beans advert banned over safety fears0
# Kazakhstan's parliament wants to rename capital after president0
# U.S., Peru seize $30 million in fake dollars, biggest bust ever0
# Atlanta hunter mistakes brother for animal, fatally shoots him2
# China websites block searches for 'Fatty Kim the Third'3
# Groin-flashing frog found in Australia3
# Hamilton freezes pet bulldog's sperm3
# Slovak brothers win burial competition with fastest, neatest grave3
# 10  docs done..
# Tobler-moan: UK fans bare sweet teeth over scaled-down chocolate bar2
# Snake scares passengers on Aeromexico plane to Mexico City3
# Clinton, Trump 'pooper' figurines on sale in Barcelona ahead of U.S. election1
# 'You're fired' - Trump effigy feels the heat on UK bonfire night2
# India's Hindu Army celebrates Trump 'victory' a few days early3
# ...

# %%
f2=open("data.json","r")
lines=[line for line in f2] 
# titles,urls,ranks=[json.loads(line)['title'] for line in lines], [json.loads(line)['url'], [json.loads(line)['rank'] for line in lines]

ranks=[json.loads(line)['rank'] for line in lines]
titles=[json.loads(line)['title'] for line in lines]
urls=[json.loads(line)['url'] for line in lines]


# unique_titles=defaultdict(int)

# for i in range(len(titles)):
#     if unique_titles[titles[i]]!=0:
#         print (titles[i],unique_titles[titles[i]],ranks[i])
#     else:
#         unique_titles[titles[i]]=ranks[i]


cnt=0
data_list=[]
while cnt !=500:
    for i in range(10):
        data={}
        data['url']=urls[cnt]
        data['title']=titles[cnt]
        data['rank']=int(ranks[cnt])
        data_list.append(data)
        cnt+=1
    print (cnt, " docs done..")
write_json(data_list)
# for r in ranks:
#     print(r)
# print (max(rank))
# Out:
# 10  docs done..
# 20  docs done..
# 30  docs done..
# 40  docs done..
# 50  docs done..
# 60  docs done..
# 70  docs done..
# 80  docs done..
# 90  docs done..
# 100  docs done..
# 110  docs done..
# 120  docs done..
# 130  docs done..
# 140  docs done..
# 150  docs done..
# 160  docs done..
# 170  docs done..
# 180  docs done..
# 190  docs done..
# 200  docs done..
# 210  docs done..
# 220  docs done..
# 230  docs done..
# 240  docs done..
# 250  docs done..
# 260  docs done..
# 270  docs done..
# 280  docs done..
# 290  docs done..
# 300  docs done..
# 310  docs done..
# 320  docs done..
# 330  docs done..
# 340  docs done..
# 350  docs done..
# 360  docs done..
# 370  docs done..
# 380  docs done..
# 390  docs done..
# 400  docs done..
# 410  docs done..
# 420  docs done..
# 430  docs done..
# 440  docs done..
# 450  docs done..
# 460  docs done..
# 470  docs done..
# 480  docs done..
# 490  docs done..
# 500  docs done..
